# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# 深度神经网络主要用于监督学习：分类或回归。然而，生成对抗网络或GANs将神经网络用于一个非常不同的目的：生成建模。
# > 生成建模是机器学习中的一项无监督学习任务，它涉及自动发现和学习输入数据中的规律或模式，以便模型可以用于生成或输出新的示例，这些示例可能是从原始数据集中抽取的。
#
# 在本教程中，我们将训练一个GAN来生成类似于MNIST数据库中手写数字的图像。

# %% [markdown]
# ## Load the Data
#
# 我们首先通过使用`torchvision.datasets`中的`MNIST`辅助类，将数据下载并导入为PyTorch数据集。

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %% [markdown]
# 请注意，我们将像素值的范围从`[0, 1]`转换为`[-1, 1]`。做这个的原因在定义生成器网络时会变得清楚。让我们来看一下数据中的一个样本张量。

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# 正如预期的那样，像素值的范围从-1到1。让我们定义一个辅助函数来反归一化并查看图像。这个函数也将对查看生成的图像非常有用。

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# 最后，让我们创建一个数据加载器来批量加载图像。

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([8, 1, 1, 4, 2, 1, 2, 9, 1, 5, 4, 2, 1, 4, 3, 9, 5, 6, 5, 4, 5, 0, 2, 5,
#         0, 6, 7, 8, 9, 3, 7, 1, 6, 9, 2, 9, 1, 8, 0, 6, 4, 2, 4, 1, 0, 8, 8, 8,
#         1, 2, 8, 0, 8, 9, 6, 7, 2, 9, 0, 4, 4, 8, 2, 7, 0, 1, 3, 6, 6, 5, 1, 9,
#         1, 3, 0, 4, 9, 3, 7, 1, 7, 6, 8, 0, 0, 3, 2, 7, 1, 7, 6, 7, 2, 5, 9, 2,
#         0, 2, 7, 0])

# %% [markdown]
# 我们还将创建一个`device`，可以用来将数据和模型移到GPU上，如果GPU可用的话。

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## 鉴别器网络
#
# 鉴别器接收图像作为输入，并试图将其分类为“真实”或“生成的”。在这个意义上，它就像任何其他神经网络一样。虽然我们可以使用CNN来实现鉴别器，但我们将使用一个简单的前馈网络，其中包含3个线性层来简化问题。我们将把每个28x28的图像视为大小为784的向量。

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# 我们在鉴别器中使用Leaky ReLU激活函数。
#
# > 与常规的ReLU函数不同，Leaky ReLU允许负值通过一个小的梯度信号。因此，它使来自鉴别器的梯度更强地流向生成器。在反向传播过程中，它不是传递梯度（斜率）为0，而是传递一个小的负梯度。
#
# 就像任何其他二分类模型一样，鉴别器的输出是一个介于0和1之间的单个数字，可以解释为输入图像是假的，即生成的概率。
#
# 让我们将鉴别器模型移动到所选择的设备上。

# %%
D.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# ## 生成器网络
#
# 生成器的输入通常是一个向量或矩阵，它被用作生成图像的种子。再次强调简单起见，我们将使用一个具有3层的前馈神经网络，输出将是一个大小为784的向量，可以将其转换为一个28x28像素的图像。

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# 我们在生成器的输出层使用TanH激活函数。
#
#
#
# > "在生成器中使用ReLU激活函数（Nair＆Hinton，2010），但输出层使用Tanh函数。我们观察到，使用有界激活函数可以使模型更快地学会饱和和覆盖训练分布的颜色空间。在鉴别器中，我们发现Leaky ReLU激活函数（Maas等人，2013）（Xu等人，2015）特别有效，尤其是对于更高分辨率的建模。"
#
# 请注意，由于TanH激活函数的输出位于`[-1,1]`的范围内，我们已经将相同的转换应用于训练数据集中的图像。让我们使用生成器生成一个输出向量，并通过转换和反归一化输出来查看它。

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# 正如人们可能期望的那样，生成器的输出基本上是随机噪声。让我们定义一个辅助函数，可以将生成器的一个批次输出保存到文件中。
#
# 让我们将生成器移动到所选择的设备上。

# %%
G.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %% [markdown]
# ## 鉴别器训练
#
# 由于鉴别器是一个二元分类模型，我们可以使用二元交叉熵损失函数来量化它在区分真实图像和生成图像方面的表现。

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# 让我们定义重置梯度和训练鉴别器的辅助函数。

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %% [markdown]
# 训练鉴别器涉及以下步骤：
#
# - 我们期望鉴别器输出1，如果图像来自真实的MNIST数据集，输出0，如果它是生成的。
#
# - 我们首先传递一批真实图像，并计算损失，将目标标签设置为1。
#
# - 然后，我们使用生成器生成一批假图像，将它们传递到鉴别器中，并计算损失，将目标标签设置为0。
#
# - 最后，我们将这两个损失相加，并使用总损失执行梯度下降来调整鉴别器的权重。
#
# 重要的是要注意，在训练鉴别器时我们不改变生成器模型的权重（`d_optimizer`仅影响`D.parameters()`）。

# %% [markdown]
# ## 生成器训练
#
# 由于生成器的输出是图像，我们不太明确如何训练生成器。这就是我们采用一种相当巧妙的技巧的地方，即将鉴别器作为损失函数的一部分。下面是它的工作原理：
#
# - 我们使用生成器生成一批图像，将它们传递到鉴别器中。
#
# - 我们通过将目标标签设置为1（真实）来计算损失。我们这样做是因为生成器的目标是“欺骗”鉴别器。
#
# - 我们使用损失进行梯度下降，即改变生成器的权重，使其更好地生成类似真实的图像。
#
# 下面是代码示例。

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## 训练模型
#
# 让我们创建一个目录，可以在其中保存从生成器产生的中间输出，以便视觉检查模型的进展。

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# 让我们保存一批真实图像，以便在查看生成的图像时进行视觉比较。

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# 我们还将定义一个辅助函数，在每个时期结束时将一批生成的图像保存到磁盘上。我们将使用一组固定的输入向量传递给生成器，以查看随着我们训练模型，单个生成的图像是如何随时间演变的。

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# 我们现在准备训练模型了。在每个时期中，我们首先训练鉴别器，然后训练生成器。如果您没有使用GPU，训练可能需要一段时间。

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0487, g_loss: 4.1750, D(x): 0.99, D(G(z)): 0.04
# Epoch [0/300], Step [400/600], d_loss: 0.0440, g_loss: 6.0865, D(x): 0.99, D(G(z)): 0.03
# Epoch [0/300], Step [600/600], d_loss: 0.0521, g_loss: 4.8570, D(x): 0.98, D(G(z)): 0.03
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0522, g_loss: 6.1235, D(x): 0.98, D(G(z)): 0.02
# Epoch [1/300], Step [400/600], d_loss: 0.3179, g_loss: 5.3366, D(x): 0.89, D(G(z)): 0.15
# Epoch [1/300], Step [600/600], d_loss: 0.1652, g_loss: 4.8549, D(x): 0.94, D(G(z)): 0.06
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.5302, g_loss: 2.9670, D(x): 0.85, D(G(z)): 0.21
# Epoch [2/300], Step [400/600], d_loss: 0.4647, g_loss: 2.0266, D(x): 0.86, D(G(z)): 0.20
# Epoch [2/300], Step [600/600], d_loss: 0.5649, g_loss: 3.9503, D(x): 0.93, D(G(z)): 0.23
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.7836, g_loss: 2.5032, D(x): 0.75, D(G(z)): 0.21
# Epoch [3/300], Step [400/600], d_loss: 0.6413, g_loss: 2.2476, D(x): 0.77, D(G(z)): 0.15
# Epoch [3/300], Step [600/600], d_loss: 0.4376, g_loss: 3.0868, D(x): 0.84, D(G(z)): 0.14
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.3837, g_loss: 2.5283, D(x): 0.88, D(G(z)): 0.14
# Epoch [4/300], Step [400/600], d_loss: 0.6419, g_loss: 2.3198, D(x): 0.79, D(G(z)): 0.24
# Epoch [4/300], Step [600/600], d_loss: 1.1844, g_loss: 1.5079, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.1841, g_loss: 3.2142, D(x): 0.95, D(G(z)): 0.10
# Epoch [5/300], Step [400/600], d_loss: 0.1537, g_loss: 3.8846, D(x): 0.95, D(G(z)): 0.08
# Epoch [5/300], Step [600/600], d_loss: 0.0908, g_loss: 3.7733, D(x): 0.97, D(G(z)): 0.05
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.1405, g_loss: 3.8842, D(x): 0.94, D(G(z)): 0.03
# Epoch [6/300], Step [400/600], d_loss: 0.2136, g_loss: 3.5697, D(x): 0.95, D(G(z)): 0.05
# Epoch [6/300], Step [600/600], d_loss: 0.1314, g_loss: 3.2982, D(x): 0.96, D(G(z)): 0.03
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.1607, g_loss: 4.7660, D(x): 0.94, D(G(z)): 0.03
# Epoch [7/300], Step [400/600], d_loss: 0.0749, g_loss: 3.6285, D(x): 0.99, D(G(z)): 0.06
# Epoch [7/300], Step [600/600], d_loss: 0.1250, g_loss: 3.5047, D(x): 0.95, D(G(z)): 0.04
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1371, g_loss: 3.7707, D(x): 0.98, D(G(z)): 0.09
# Epoch [8/300], Step [400/600], d_loss: 0.1884, g_loss: 5.0144, D(x): 0.92, D(G(z)): 0.04
# Epoch [8/300], Step [600/600], d_loss: 0.0468, g_loss: 5.8524, D(x): 0.98, D(G(z)): 0.02
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.0986, g_loss: 3.5062, D(x): 0.99, D(G(z)): 0.07
# Epoch [9/300], Step [400/600], d_loss: 0.5899, g_loss: 6.1163, D(x): 0.88, D(G(z)): 0.05
# Epoch [9/300], Step [600/600], d_loss: 0.1653, g_loss: 4.5441, D(x): 0.95, D(G(z)): 0.08
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.2239, g_loss: 4.6641, D(x): 0.94, D(G(z)): 0.06
# Epoch [10/300], Step [400/600], d_loss: 0.3440, g_loss: 3.6449, D(x): 0.90, D(G(z)): 0.04
# Epoch [10/300], Step [600/600], d_loss: 0.2802, g_loss: 4.4795, D(x): 0.92, D(G(z)): 0.02
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.1515, g_loss: 4.1925, D(x): 0.95, D(G(z)): 0.05
# Epoch [11/300], Step [400/600], d_loss: 0.1533, g_loss: 4.2184, D(x): 0.95, D(G(z)): 0.03
# Epoch [11/300], Step [600/600], d_loss: 0.2609, g_loss: 3.4719, D(x): 0.91, D(G(z)): 0.07
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.1251, g_loss: 4.9064, D(x): 0.95, D(G(z)): 0.03
# Epoch [12/300], Step [400/600], d_loss: 0.1551, g_loss: 4.2202, D(x): 0.97, D(G(z)): 0.10
# Epoch [12/300], Step [600/600], d_loss: 0.3667, g_loss: 5.1945, D(x): 0.92, D(G(z)): 0.11
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.1756, g_loss: 5.3993, D(x): 0.94, D(G(z)): 0.05
# Epoch [13/300], Step [400/600], d_loss: 0.1390, g_loss: 4.6634, D(x): 0.94, D(G(z)): 0.02
# Epoch [13/300], Step [600/600], d_loss: 0.2717, g_loss: 3.7745, D(x): 0.92, D(G(z)): 0.07
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.0994, g_loss: 4.8510, D(x): 0.95, D(G(z)): 0.03
# Epoch [14/300], Step [400/600], d_loss: 0.3155, g_loss: 4.3522, D(x): 0.92, D(G(z)): 0.09
# Epoch [14/300], Step [600/600], d_loss: 0.2059, g_loss: 5.2175, D(x): 0.91, D(G(z)): 0.01
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.1196, g_loss: 4.2890, D(x): 0.97, D(G(z)): 0.05
# Epoch [15/300], Step [400/600], d_loss: 0.2080, g_loss: 4.4762, D(x): 0.96, D(G(z)): 0.12
# Epoch [15/300], Step [600/600], d_loss: 0.2823, g_loss: 4.2702, D(x): 0.89, D(G(z)): 0.04
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.2968, g_loss: 4.3530, D(x): 0.97, D(G(z)): 0.18
# Epoch [16/300], Step [400/600], d_loss: 0.2772, g_loss: 3.2909, D(x): 0.90, D(G(z)): 0.05
# Epoch [16/300], Step [600/600], d_loss: 0.2705, g_loss: 3.9515, D(x): 0.89, D(G(z)): 0.06
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.3781, g_loss: 4.2622, D(x): 0.89, D(G(z)): 0.05
# Epoch [17/300], Step [400/600], d_loss: 0.2656, g_loss: 4.1340, D(x): 0.89, D(G(z)): 0.06
# Epoch [17/300], Step [600/600], d_loss: 0.2370, g_loss: 5.0028, D(x): 0.90, D(G(z)): 0.05
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.4298, g_loss: 5.3734, D(x): 0.86, D(G(z)): 0.05
# Epoch [18/300], Step [400/600], d_loss: 0.3853, g_loss: 5.0470, D(x): 0.93, D(G(z)): 0.08
# Epoch [18/300], Step [600/600], d_loss: 0.2079, g_loss: 3.9867, D(x): 0.92, D(G(z)): 0.07
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.2225, g_loss: 5.8261, D(x): 0.95, D(G(z)): 0.05
# Epoch [19/300], Step [400/600], d_loss: 0.1601, g_loss: 4.0032, D(x): 0.93, D(G(z)): 0.05
# Epoch [19/300], Step [600/600], d_loss: 0.1663, g_loss: 5.4010, D(x): 0.93, D(G(z)): 0.05
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.2464, g_loss: 5.4690, D(x): 0.93, D(G(z)): 0.05
# Epoch [20/300], Step [400/600], d_loss: 0.3657, g_loss: 3.6582, D(x): 0.94, D(G(z)): 0.13
# Epoch [20/300], Step [600/600], d_loss: 0.2176, g_loss: 3.8071, D(x): 0.97, D(G(z)): 0.13
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.2350, g_loss: 5.6252, D(x): 0.91, D(G(z)): 0.02
# Epoch [21/300], Step [400/600], d_loss: 0.1676, g_loss: 3.8496, D(x): 0.94, D(G(z)): 0.05
# Epoch [21/300], Step [600/600], d_loss: 0.1793, g_loss: 5.8731, D(x): 0.91, D(G(z)): 0.02
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.2241, g_loss: 6.1621, D(x): 0.91, D(G(z)): 0.02
# Epoch [22/300], Step [400/600], d_loss: 0.2970, g_loss: 4.2270, D(x): 0.91, D(G(z)): 0.08
# Epoch [22/300], Step [600/600], d_loss: 0.3815, g_loss: 5.1230, D(x): 0.93, D(G(z)): 0.10
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.2489, g_loss: 5.0000, D(x): 0.93, D(G(z)): 0.09
# Epoch [23/300], Step [400/600], d_loss: 0.1816, g_loss: 6.7612, D(x): 0.93, D(G(z)): 0.04
# Epoch [23/300], Step [600/600], d_loss: 0.2697, g_loss: 5.0688, D(x): 0.91, D(G(z)): 0.09
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.1994, g_loss: 5.2669, D(x): 0.93, D(G(z)): 0.05
# Epoch [24/300], Step [400/600], d_loss: 0.2491, g_loss: 4.6204, D(x): 0.95, D(G(z)): 0.09
# Epoch [24/300], Step [600/600], d_loss: 0.2019, g_loss: 5.4803, D(x): 0.94, D(G(z)): 0.07
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.2372, g_loss: 5.0002, D(x): 0.91, D(G(z)): 0.05
# Epoch [25/300], Step [400/600], d_loss: 0.3500, g_loss: 4.8611, D(x): 0.91, D(G(z)): 0.07
# Epoch [25/300], Step [600/600], d_loss: 0.3329, g_loss: 4.0048, D(x): 0.90, D(G(z)): 0.10
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.2979, g_loss: 3.0602, D(x): 0.90, D(G(z)): 0.10
# Epoch [26/300], Step [400/600], d_loss: 0.2078, g_loss: 4.6676, D(x): 0.89, D(G(z)): 0.04
# Epoch [26/300], Step [600/600], d_loss: 0.1433, g_loss: 5.3141, D(x): 0.94, D(G(z)): 0.05
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.3432, g_loss: 3.9042, D(x): 0.93, D(G(z)): 0.12
# Epoch [27/300], Step [400/600], d_loss: 0.3407, g_loss: 5.5271, D(x): 0.94, D(G(z)): 0.15
# Epoch [27/300], Step [600/600], d_loss: 0.4579, g_loss: 3.8476, D(x): 0.89, D(G(z)): 0.12
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.4165, g_loss: 3.3638, D(x): 0.91, D(G(z)): 0.16
# Epoch [28/300], Step [400/600], d_loss: 0.1689, g_loss: 4.4985, D(x): 0.95, D(G(z)): 0.07
# Epoch [28/300], Step [600/600], d_loss: 0.3764, g_loss: 5.1592, D(x): 0.86, D(G(z)): 0.05
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.2639, g_loss: 4.3030, D(x): 0.91, D(G(z)): 0.07
# Epoch [29/300], Step [400/600], d_loss: 0.2352, g_loss: 4.7014, D(x): 0.94, D(G(z)): 0.08
# Epoch [29/300], Step [600/600], d_loss: 0.2658, g_loss: 4.0785, D(x): 0.93, D(G(z)): 0.10
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.5180, g_loss: 2.2976, D(x): 0.87, D(G(z)): 0.16
# Epoch [30/300], Step [400/600], d_loss: 0.3485, g_loss: 4.3997, D(x): 0.90, D(G(z)): 0.12
# Epoch [30/300], Step [600/600], d_loss: 0.3433, g_loss: 3.5350, D(x): 0.93, D(G(z)): 0.15
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.2112, g_loss: 4.8774, D(x): 0.92, D(G(z)): 0.05
# Epoch [31/300], Step [400/600], d_loss: 0.2900, g_loss: 4.6631, D(x): 0.91, D(G(z)): 0.09
# Epoch [31/300], Step [600/600], d_loss: 0.2088, g_loss: 4.5358, D(x): 0.94, D(G(z)): 0.09
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.3087, g_loss: 3.9326, D(x): 0.91, D(G(z)): 0.10
# Epoch [32/300], Step [400/600], d_loss: 0.3366, g_loss: 3.7784, D(x): 0.90, D(G(z)): 0.10
# Epoch [32/300], Step [600/600], d_loss: 0.3774, g_loss: 4.0076, D(x): 0.90, D(G(z)): 0.11
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.5353, g_loss: 3.1968, D(x): 0.86, D(G(z)): 0.18
# Epoch [33/300], Step [400/600], d_loss: 0.5276, g_loss: 3.9372, D(x): 0.84, D(G(z)): 0.06
# Epoch [33/300], Step [600/600], d_loss: 0.2936, g_loss: 4.3179, D(x): 0.87, D(G(z)): 0.06
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.5429, g_loss: 2.8319, D(x): 0.83, D(G(z)): 0.11
# Epoch [34/300], Step [400/600], d_loss: 0.4554, g_loss: 3.2536, D(x): 0.86, D(G(z)): 0.12
# Epoch [34/300], Step [600/600], d_loss: 0.4167, g_loss: 2.7858, D(x): 0.84, D(G(z)): 0.10
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.4187, g_loss: 2.8153, D(x): 0.86, D(G(z)): 0.10
# Epoch [35/300], Step [400/600], d_loss: 0.4812, g_loss: 2.7098, D(x): 0.84, D(G(z)): 0.13
# Epoch [35/300], Step [600/600], d_loss: 0.4708, g_loss: 3.1642, D(x): 0.82, D(G(z)): 0.10
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.5493, g_loss: 3.2247, D(x): 0.78, D(G(z)): 0.08
# Epoch [36/300], Step [400/600], d_loss: 0.4984, g_loss: 3.6103, D(x): 0.85, D(G(z)): 0.11
# Epoch [36/300], Step [600/600], d_loss: 0.7507, g_loss: 3.5714, D(x): 0.76, D(G(z)): 0.10
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.4433, g_loss: 2.9639, D(x): 0.86, D(G(z)): 0.15
# Epoch [37/300], Step [400/600], d_loss: 0.4601, g_loss: 3.2292, D(x): 0.89, D(G(z)): 0.20
# Epoch [37/300], Step [600/600], d_loss: 0.5169, g_loss: 3.0584, D(x): 0.82, D(G(z)): 0.13
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.5516, g_loss: 1.9057, D(x): 0.95, D(G(z)): 0.25
# Epoch [38/300], Step [400/600], d_loss: 0.5422, g_loss: 3.2600, D(x): 0.83, D(G(z)): 0.18
# Epoch [38/300], Step [600/600], d_loss: 0.3514, g_loss: 3.2888, D(x): 0.88, D(G(z)): 0.13
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.4044, g_loss: 3.8700, D(x): 0.88, D(G(z)): 0.11
# Epoch [39/300], Step [400/600], d_loss: 0.3539, g_loss: 4.5795, D(x): 0.86, D(G(z)): 0.09
# Epoch [39/300], Step [600/600], d_loss: 0.3048, g_loss: 3.2220, D(x): 0.90, D(G(z)): 0.08
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.3584, g_loss: 4.2164, D(x): 0.89, D(G(z)): 0.14
# Epoch [40/300], Step [400/600], d_loss: 0.3417, g_loss: 3.5742, D(x): 0.90, D(G(z)): 0.11
# Epoch [40/300], Step [600/600], d_loss: 0.4475, g_loss: 3.4894, D(x): 0.89, D(G(z)): 0.14
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.5123, g_loss: 3.3054, D(x): 0.85, D(G(z)): 0.16
# Epoch [41/300], Step [400/600], d_loss: 0.3099, g_loss: 3.1013, D(x): 0.89, D(G(z)): 0.11
# Epoch [41/300], Step [600/600], d_loss: 0.4498, g_loss: 2.6253, D(x): 0.85, D(G(z)): 0.14
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.3986, g_loss: 2.3909, D(x): 0.87, D(G(z)): 0.14
# Epoch [42/300], Step [400/600], d_loss: 0.3878, g_loss: 3.7855, D(x): 0.93, D(G(z)): 0.22
# Epoch [42/300], Step [600/600], d_loss: 0.4788, g_loss: 4.0172, D(x): 0.81, D(G(z)): 0.05
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.4942, g_loss: 2.5380, D(x): 0.83, D(G(z)): 0.15
# Epoch [43/300], Step [400/600], d_loss: 0.3456, g_loss: 3.5392, D(x): 0.91, D(G(z)): 0.16
# Epoch [43/300], Step [600/600], d_loss: 0.4748, g_loss: 2.5616, D(x): 0.84, D(G(z)): 0.14
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.5435, g_loss: 2.8775, D(x): 0.79, D(G(z)): 0.12
# Epoch [44/300], Step [400/600], d_loss: 0.6901, g_loss: 3.3549, D(x): 0.72, D(G(z)): 0.06
# Epoch [44/300], Step [600/600], d_loss: 0.6118, g_loss: 3.1050, D(x): 0.76, D(G(z)): 0.09
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.5957, g_loss: 2.3115, D(x): 0.76, D(G(z)): 0.10
# Epoch [45/300], Step [400/600], d_loss: 0.4084, g_loss: 2.8829, D(x): 0.86, D(G(z)): 0.14
# Epoch [45/300], Step [600/600], d_loss: 0.4844, g_loss: 2.3856, D(x): 0.84, D(G(z)): 0.18
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.5708, g_loss: 3.3304, D(x): 0.81, D(G(z)): 0.19
# Epoch [46/300], Step [400/600], d_loss: 0.6077, g_loss: 2.6499, D(x): 0.79, D(G(z)): 0.15
# Epoch [46/300], Step [600/600], d_loss: 0.5611, g_loss: 3.1018, D(x): 0.78, D(G(z)): 0.11
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.5970, g_loss: 2.7379, D(x): 0.75, D(G(z)): 0.07
# Epoch [47/300], Step [400/600], d_loss: 0.3608, g_loss: 2.4218, D(x): 0.91, D(G(z)): 0.18
# Epoch [47/300], Step [600/600], d_loss: 0.4511, g_loss: 4.5311, D(x): 0.85, D(G(z)): 0.13
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.3776, g_loss: 3.3409, D(x): 0.88, D(G(z)): 0.12
# Epoch [48/300], Step [400/600], d_loss: 0.3803, g_loss: 3.5677, D(x): 0.88, D(G(z)): 0.12
# Epoch [48/300], Step [600/600], d_loss: 0.4772, g_loss: 2.9823, D(x): 0.95, D(G(z)): 0.25
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.4550, g_loss: 2.6112, D(x): 0.87, D(G(z)): 0.18
# Epoch [49/300], Step [400/600], d_loss: 0.5334, g_loss: 3.5233, D(x): 0.82, D(G(z)): 0.13
# Epoch [49/300], Step [600/600], d_loss: 0.3920, g_loss: 2.9630, D(x): 0.86, D(G(z)): 0.13
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.5066, g_loss: 3.2540, D(x): 0.84, D(G(z)): 0.17
# Epoch [50/300], Step [400/600], d_loss: 0.4856, g_loss: 3.7104, D(x): 0.80, D(G(z)): 0.09
# Epoch [50/300], Step [600/600], d_loss: 0.4266, g_loss: 3.6226, D(x): 0.84, D(G(z)): 0.10
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.6762, g_loss: 2.3717, D(x): 0.83, D(G(z)): 0.23
# Epoch [51/300], Step [400/600], d_loss: 0.5046, g_loss: 2.6169, D(x): 0.83, D(G(z)): 0.16
# Epoch [51/300], Step [600/600], d_loss: 0.5351, g_loss: 2.4983, D(x): 0.86, D(G(z)): 0.21
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.7955, g_loss: 1.9600, D(x): 0.76, D(G(z)): 0.24
# Epoch [52/300], Step [400/600], d_loss: 0.5242, g_loss: 2.4763, D(x): 0.83, D(G(z)): 0.17
# Epoch [52/300], Step [600/600], d_loss: 0.6176, g_loss: 2.2657, D(x): 0.84, D(G(z)): 0.25
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.7915, g_loss: 2.1258, D(x): 0.82, D(G(z)): 0.33
# Epoch [53/300], Step [400/600], d_loss: 0.4659, g_loss: 3.0771, D(x): 0.81, D(G(z)): 0.11
# Epoch [53/300], Step [600/600], d_loss: 0.4679, g_loss: 2.7375, D(x): 0.86, D(G(z)): 0.18
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.5227, g_loss: 3.0860, D(x): 0.83, D(G(z)): 0.19
# Epoch [54/300], Step [400/600], d_loss: 0.4935, g_loss: 3.0689, D(x): 0.80, D(G(z)): 0.13
# Epoch [54/300], Step [600/600], d_loss: 0.5517, g_loss: 1.6663, D(x): 0.80, D(G(z)): 0.17
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.5199, g_loss: 2.9580, D(x): 0.81, D(G(z)): 0.17
# Epoch [55/300], Step [400/600], d_loss: 0.7556, g_loss: 2.1161, D(x): 0.79, D(G(z)): 0.23
# Epoch [55/300], Step [600/600], d_loss: 0.6849, g_loss: 2.1333, D(x): 0.76, D(G(z)): 0.21
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.9181, g_loss: 2.1153, D(x): 0.81, D(G(z)): 0.36
# Epoch [56/300], Step [400/600], d_loss: 0.5153, g_loss: 1.7809, D(x): 0.84, D(G(z)): 0.21
# Epoch [56/300], Step [600/600], d_loss: 0.6022, g_loss: 2.6108, D(x): 0.78, D(G(z)): 0.14
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.5361, g_loss: 2.9057, D(x): 0.84, D(G(z)): 0.20
# Epoch [57/300], Step [400/600], d_loss: 0.4845, g_loss: 2.7279, D(x): 0.82, D(G(z)): 0.15
# Epoch [57/300], Step [600/600], d_loss: 0.6228, g_loss: 2.2017, D(x): 0.81, D(G(z)): 0.21
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.6499, g_loss: 2.2019, D(x): 0.81, D(G(z)): 0.23
# Epoch [58/300], Step [400/600], d_loss: 0.7078, g_loss: 2.4698, D(x): 0.83, D(G(z)): 0.26
# Epoch [58/300], Step [600/600], d_loss: 0.6064, g_loss: 2.5969, D(x): 0.86, D(G(z)): 0.24
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.7143, g_loss: 1.9362, D(x): 0.74, D(G(z)): 0.17
# Epoch [59/300], Step [400/600], d_loss: 0.5136, g_loss: 2.3443, D(x): 0.79, D(G(z)): 0.12
# Epoch [59/300], Step [600/600], d_loss: 0.5334, g_loss: 1.9958, D(x): 0.87, D(G(z)): 0.21
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.3972, g_loss: 2.4399, D(x): 0.87, D(G(z)): 0.14
# Epoch [60/300], Step [400/600], d_loss: 0.5138, g_loss: 2.2201, D(x): 0.80, D(G(z)): 0.15
# Epoch [60/300], Step [600/600], d_loss: 0.5847, g_loss: 1.7910, D(x): 0.80, D(G(z)): 0.18
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.4957, g_loss: 2.2576, D(x): 0.82, D(G(z)): 0.16
# Epoch [61/300], Step [400/600], d_loss: 0.4843, g_loss: 3.3111, D(x): 0.87, D(G(z)): 0.17
# Epoch [61/300], Step [600/600], d_loss: 0.8423, g_loss: 2.8958, D(x): 0.70, D(G(z)): 0.16
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.5924, g_loss: 3.0488, D(x): 0.81, D(G(z)): 0.18
# Epoch [62/300], Step [400/600], d_loss: 0.6674, g_loss: 2.6265, D(x): 0.76, D(G(z)): 0.15
# Epoch [62/300], Step [600/600], d_loss: 0.5682, g_loss: 2.3601, D(x): 0.80, D(G(z)): 0.15
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.5308, g_loss: 2.9844, D(x): 0.85, D(G(z)): 0.20
# Epoch [63/300], Step [400/600], d_loss: 0.7008, g_loss: 2.7799, D(x): 0.77, D(G(z)): 0.18
# Epoch [63/300], Step [600/600], d_loss: 0.4299, g_loss: 2.5641, D(x): 0.86, D(G(z)): 0.17
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.7668, g_loss: 2.4849, D(x): 0.73, D(G(z)): 0.17
# Epoch [64/300], Step [400/600], d_loss: 0.5813, g_loss: 1.9740, D(x): 0.81, D(G(z)): 0.20
# Epoch [64/300], Step [600/600], d_loss: 0.6280, g_loss: 2.4320, D(x): 0.76, D(G(z)): 0.13
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.7922, g_loss: 1.7652, D(x): 0.74, D(G(z)): 0.22
# Epoch [65/300], Step [400/600], d_loss: 0.6116, g_loss: 3.2069, D(x): 0.77, D(G(z)): 0.15
# Epoch [65/300], Step [600/600], d_loss: 0.6930, g_loss: 2.2440, D(x): 0.84, D(G(z)): 0.26
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.6204, g_loss: 2.5568, D(x): 0.81, D(G(z)): 0.22
# Epoch [66/300], Step [400/600], d_loss: 0.6455, g_loss: 2.1801, D(x): 0.85, D(G(z)): 0.27
# Epoch [66/300], Step [600/600], d_loss: 0.6278, g_loss: 1.5160, D(x): 0.86, D(G(z)): 0.27
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.4778, g_loss: 2.4710, D(x): 0.85, D(G(z)): 0.19
# Epoch [67/300], Step [400/600], d_loss: 0.9143, g_loss: 2.2392, D(x): 0.64, D(G(z)): 0.14
# Epoch [67/300], Step [600/600], d_loss: 0.7500, g_loss: 2.0342, D(x): 0.79, D(G(z)): 0.25
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.5617, g_loss: 2.1579, D(x): 0.82, D(G(z)): 0.18
# Epoch [68/300], Step [400/600], d_loss: 0.8736, g_loss: 1.5258, D(x): 0.75, D(G(z)): 0.27
# Epoch [68/300], Step [600/600], d_loss: 0.7169, g_loss: 1.9003, D(x): 0.76, D(G(z)): 0.23
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.7260, g_loss: 1.9323, D(x): 0.71, D(G(z)): 0.13
# Epoch [69/300], Step [400/600], d_loss: 0.6610, g_loss: 1.9937, D(x): 0.71, D(G(z)): 0.15
# Epoch [69/300], Step [600/600], d_loss: 0.6799, g_loss: 2.2686, D(x): 0.77, D(G(z)): 0.20
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.5925, g_loss: 2.2459, D(x): 0.81, D(G(z)): 0.23
# Epoch [70/300], Step [400/600], d_loss: 0.8458, g_loss: 2.0865, D(x): 0.81, D(G(z)): 0.31
# Epoch [70/300], Step [600/600], d_loss: 0.6284, g_loss: 1.7641, D(x): 0.78, D(G(z)): 0.21
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.5774, g_loss: 2.1673, D(x): 0.79, D(G(z)): 0.18
# Epoch [71/300], Step [400/600], d_loss: 0.6426, g_loss: 2.4357, D(x): 0.80, D(G(z)): 0.21
# Epoch [71/300], Step [600/600], d_loss: 0.7881, g_loss: 1.9645, D(x): 0.81, D(G(z)): 0.32
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.7594, g_loss: 2.2622, D(x): 0.75, D(G(z)): 0.21
# Epoch [72/300], Step [400/600], d_loss: 0.5553, g_loss: 2.3149, D(x): 0.82, D(G(z)): 0.19
# Epoch [72/300], Step [600/600], d_loss: 0.9156, g_loss: 1.5667, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.5580, g_loss: 2.2017, D(x): 0.81, D(G(z)): 0.18
# Epoch [73/300], Step [400/600], d_loss: 0.5501, g_loss: 1.8564, D(x): 0.86, D(G(z)): 0.25
# Epoch [73/300], Step [600/600], d_loss: 0.7555, g_loss: 2.3403, D(x): 0.77, D(G(z)): 0.23
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.6144, g_loss: 2.6454, D(x): 0.84, D(G(z)): 0.28
# Epoch [74/300], Step [400/600], d_loss: 0.8074, g_loss: 2.2769, D(x): 0.83, D(G(z)): 0.35
# Epoch [74/300], Step [600/600], d_loss: 0.5897, g_loss: 2.5319, D(x): 0.75, D(G(z)): 0.14
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.6683, g_loss: 1.8782, D(x): 0.78, D(G(z)): 0.23
# Epoch [75/300], Step [400/600], d_loss: 0.7110, g_loss: 1.9798, D(x): 0.79, D(G(z)): 0.25
# Epoch [75/300], Step [600/600], d_loss: 0.6859, g_loss: 1.9405, D(x): 0.86, D(G(z)): 0.31
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.7282, g_loss: 2.2525, D(x): 0.73, D(G(z)): 0.17
# Epoch [76/300], Step [400/600], d_loss: 0.5907, g_loss: 1.9558, D(x): 0.81, D(G(z)): 0.24
# Epoch [76/300], Step [600/600], d_loss: 0.6010, g_loss: 2.5716, D(x): 0.78, D(G(z)): 0.18
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.6159, g_loss: 2.3827, D(x): 0.86, D(G(z)): 0.27
# Epoch [77/300], Step [400/600], d_loss: 0.6293, g_loss: 2.1874, D(x): 0.76, D(G(z)): 0.17
# Epoch [77/300], Step [600/600], d_loss: 0.6868, g_loss: 2.1204, D(x): 0.83, D(G(z)): 0.27
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.8120, g_loss: 1.8426, D(x): 0.83, D(G(z)): 0.35
# Epoch [78/300], Step [400/600], d_loss: 0.9613, g_loss: 1.8265, D(x): 0.62, D(G(z)): 0.20
# Epoch [78/300], Step [600/600], d_loss: 0.8985, g_loss: 1.5891, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.6786, g_loss: 2.4280, D(x): 0.74, D(G(z)): 0.18
# Epoch [79/300], Step [400/600], d_loss: 0.6501, g_loss: 1.9276, D(x): 0.82, D(G(z)): 0.28
# Epoch [79/300], Step [600/600], d_loss: 0.7728, g_loss: 1.9786, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.7877, g_loss: 2.3932, D(x): 0.71, D(G(z)): 0.20
# Epoch [80/300], Step [400/600], d_loss: 1.0079, g_loss: 2.1201, D(x): 0.70, D(G(z)): 0.29
# Epoch [80/300], Step [600/600], d_loss: 0.6316, g_loss: 2.9004, D(x): 0.74, D(G(z)): 0.17
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.5828, g_loss: 2.1355, D(x): 0.82, D(G(z)): 0.23
# Epoch [81/300], Step [400/600], d_loss: 0.6580, g_loss: 2.4139, D(x): 0.79, D(G(z)): 0.22
# Epoch [81/300], Step [600/600], d_loss: 0.8485, g_loss: 1.5237, D(x): 0.79, D(G(z)): 0.34
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.7485, g_loss: 1.9748, D(x): 0.76, D(G(z)): 0.24
# Epoch [82/300], Step [400/600], d_loss: 0.6523, g_loss: 2.0762, D(x): 0.88, D(G(z)): 0.31
# Epoch [82/300], Step [600/600], d_loss: 0.8455, g_loss: 2.5479, D(x): 0.69, D(G(z)): 0.18
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.7872, g_loss: 2.3681, D(x): 0.79, D(G(z)): 0.28
# Epoch [83/300], Step [400/600], d_loss: 0.8213, g_loss: 1.4314, D(x): 0.81, D(G(z)): 0.35
# Epoch [83/300], Step [600/600], d_loss: 0.7530, g_loss: 1.8531, D(x): 0.72, D(G(z)): 0.19
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.6477, g_loss: 2.0980, D(x): 0.74, D(G(z)): 0.16
# Epoch [84/300], Step [400/600], d_loss: 0.6768, g_loss: 1.7583, D(x): 0.81, D(G(z)): 0.28
# Epoch [84/300], Step [600/600], d_loss: 0.6107, g_loss: 2.2625, D(x): 0.75, D(G(z)): 0.18
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.7644, g_loss: 1.6957, D(x): 0.82, D(G(z)): 0.32
# Epoch [85/300], Step [400/600], d_loss: 0.6504, g_loss: 2.0908, D(x): 0.81, D(G(z)): 0.28
# Epoch [85/300], Step [600/600], d_loss: 0.6345, g_loss: 2.1108, D(x): 0.76, D(G(z)): 0.20
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.8400, g_loss: 1.8655, D(x): 0.74, D(G(z)): 0.28
# Epoch [86/300], Step [400/600], d_loss: 0.7468, g_loss: 2.2663, D(x): 0.75, D(G(z)): 0.24
# Epoch [86/300], Step [600/600], d_loss: 0.8382, g_loss: 1.9348, D(x): 0.76, D(G(z)): 0.28
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.8360, g_loss: 2.4365, D(x): 0.68, D(G(z)): 0.19
# Epoch [87/300], Step [400/600], d_loss: 0.8395, g_loss: 2.2928, D(x): 0.71, D(G(z)): 0.24
# Epoch [87/300], Step [600/600], d_loss: 0.8077, g_loss: 1.4961, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.8239, g_loss: 1.6331, D(x): 0.81, D(G(z)): 0.31
# Epoch [88/300], Step [400/600], d_loss: 0.9494, g_loss: 2.1293, D(x): 0.80, D(G(z)): 0.36
# Epoch [88/300], Step [600/600], d_loss: 0.6002, g_loss: 2.0438, D(x): 0.77, D(G(z)): 0.17
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.7052, g_loss: 2.3855, D(x): 0.81, D(G(z)): 0.29
# Epoch [89/300], Step [400/600], d_loss: 0.8177, g_loss: 1.6668, D(x): 0.81, D(G(z)): 0.33
# Epoch [89/300], Step [600/600], d_loss: 0.8280, g_loss: 1.8776, D(x): 0.81, D(G(z)): 0.31
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.7219, g_loss: 2.4800, D(x): 0.68, D(G(z)): 0.14
# Epoch [90/300], Step [400/600], d_loss: 0.8566, g_loss: 2.1662, D(x): 0.66, D(G(z)): 0.14
# Epoch [90/300], Step [600/600], d_loss: 0.8291, g_loss: 2.2124, D(x): 0.65, D(G(z)): 0.14
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.6417, g_loss: 2.0605, D(x): 0.82, D(G(z)): 0.27
# Epoch [91/300], Step [400/600], d_loss: 0.8966, g_loss: 1.5458, D(x): 0.74, D(G(z)): 0.27
# Epoch [91/300], Step [600/600], d_loss: 0.7464, g_loss: 2.1917, D(x): 0.82, D(G(z)): 0.33
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.8576, g_loss: 1.4059, D(x): 0.78, D(G(z)): 0.33
# Epoch [92/300], Step [400/600], d_loss: 0.7833, g_loss: 2.0155, D(x): 0.75, D(G(z)): 0.23
# Epoch [92/300], Step [600/600], d_loss: 0.8773, g_loss: 2.2863, D(x): 0.69, D(G(z)): 0.19
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.8802, g_loss: 1.6202, D(x): 0.70, D(G(z)): 0.25
# Epoch [93/300], Step [400/600], d_loss: 0.8835, g_loss: 1.9342, D(x): 0.76, D(G(z)): 0.32
# Epoch [93/300], Step [600/600], d_loss: 0.6271, g_loss: 2.1252, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.7394, g_loss: 2.1002, D(x): 0.72, D(G(z)): 0.19
# Epoch [94/300], Step [400/600], d_loss: 0.7805, g_loss: 1.8217, D(x): 0.70, D(G(z)): 0.20
# Epoch [94/300], Step [600/600], d_loss: 0.7588, g_loss: 1.9400, D(x): 0.87, D(G(z)): 0.37
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.9817, g_loss: 1.8396, D(x): 0.83, D(G(z)): 0.40
# Epoch [95/300], Step [400/600], d_loss: 0.7417, g_loss: 2.0916, D(x): 0.74, D(G(z)): 0.21
# Epoch [95/300], Step [600/600], d_loss: 0.8519, g_loss: 1.9803, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.7869, g_loss: 1.4878, D(x): 0.79, D(G(z)): 0.32
# Epoch [96/300], Step [400/600], d_loss: 0.8692, g_loss: 2.1965, D(x): 0.71, D(G(z)): 0.25
# Epoch [96/300], Step [600/600], d_loss: 0.8317, g_loss: 1.6912, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.9455, g_loss: 1.4347, D(x): 0.78, D(G(z)): 0.37
# Epoch [97/300], Step [400/600], d_loss: 0.7101, g_loss: 1.5800, D(x): 0.79, D(G(z)): 0.28
# Epoch [97/300], Step [600/600], d_loss: 1.0571, g_loss: 1.2925, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.9953, g_loss: 1.5274, D(x): 0.64, D(G(z)): 0.28
# Epoch [98/300], Step [400/600], d_loss: 0.8307, g_loss: 1.9075, D(x): 0.68, D(G(z)): 0.23
# Epoch [98/300], Step [600/600], d_loss: 0.8576, g_loss: 2.2656, D(x): 0.80, D(G(z)): 0.34
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.9813, g_loss: 1.6840, D(x): 0.69, D(G(z)): 0.28
# Epoch [99/300], Step [400/600], d_loss: 0.6048, g_loss: 2.5063, D(x): 0.76, D(G(z)): 0.15
# Epoch [99/300], Step [600/600], d_loss: 1.0477, g_loss: 1.4974, D(x): 0.73, D(G(z)): 0.38
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.8290, g_loss: 2.1873, D(x): 0.73, D(G(z)): 0.28
# Epoch [100/300], Step [400/600], d_loss: 0.8969, g_loss: 2.4326, D(x): 0.66, D(G(z)): 0.20
# Epoch [100/300], Step [600/600], d_loss: 0.9084, g_loss: 2.1009, D(x): 0.65, D(G(z)): 0.17
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.8198, g_loss: 1.6701, D(x): 0.72, D(G(z)): 0.25
# Epoch [101/300], Step [400/600], d_loss: 1.0911, g_loss: 1.7360, D(x): 0.72, D(G(z)): 0.38
# Epoch [101/300], Step [600/600], d_loss: 0.8624, g_loss: 1.7031, D(x): 0.77, D(G(z)): 0.32
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.8069, g_loss: 1.6270, D(x): 0.75, D(G(z)): 0.31
# Epoch [102/300], Step [400/600], d_loss: 0.8117, g_loss: 1.7220, D(x): 0.83, D(G(z)): 0.35
# Epoch [102/300], Step [600/600], d_loss: 0.7557, g_loss: 1.7941, D(x): 0.73, D(G(z)): 0.24
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.7720, g_loss: 1.9245, D(x): 0.80, D(G(z)): 0.30
# Epoch [103/300], Step [400/600], d_loss: 0.8221, g_loss: 1.6076, D(x): 0.73, D(G(z)): 0.27
# Epoch [103/300], Step [600/600], d_loss: 0.8489, g_loss: 1.7662, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.8606, g_loss: 1.9015, D(x): 0.68, D(G(z)): 0.22
# Epoch [104/300], Step [400/600], d_loss: 0.8679, g_loss: 1.9890, D(x): 0.83, D(G(z)): 0.35
# Epoch [104/300], Step [600/600], d_loss: 1.0357, g_loss: 2.4714, D(x): 0.58, D(G(z)): 0.16
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.8444, g_loss: 1.6626, D(x): 0.74, D(G(z)): 0.31
# Epoch [105/300], Step [400/600], d_loss: 0.9782, g_loss: 1.9787, D(x): 0.68, D(G(z)): 0.27
# Epoch [105/300], Step [600/600], d_loss: 0.9760, g_loss: 1.7675, D(x): 0.64, D(G(z)): 0.23
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.9703, g_loss: 1.8699, D(x): 0.76, D(G(z)): 0.37
# Epoch [106/300], Step [400/600], d_loss: 0.7549, g_loss: 1.6488, D(x): 0.74, D(G(z)): 0.25
# Epoch [106/300], Step [600/600], d_loss: 0.7989, g_loss: 2.1387, D(x): 0.73, D(G(z)): 0.22
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.7624, g_loss: 1.8013, D(x): 0.74, D(G(z)): 0.20
# Epoch [107/300], Step [400/600], d_loss: 0.7930, g_loss: 2.1178, D(x): 0.75, D(G(z)): 0.28
# Epoch [107/300], Step [600/600], d_loss: 1.1835, g_loss: 2.0432, D(x): 0.73, D(G(z)): 0.40
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 1.0416, g_loss: 1.5394, D(x): 0.74, D(G(z)): 0.35
# Epoch [108/300], Step [400/600], d_loss: 0.6769, g_loss: 1.5372, D(x): 0.78, D(G(z)): 0.24
# Epoch [108/300], Step [600/600], d_loss: 1.0139, g_loss: 1.4536, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.7141, g_loss: 1.8719, D(x): 0.78, D(G(z)): 0.28
# Epoch [109/300], Step [400/600], d_loss: 0.8665, g_loss: 1.8411, D(x): 0.72, D(G(z)): 0.29
# Epoch [109/300], Step [600/600], d_loss: 0.7168, g_loss: 1.9326, D(x): 0.74, D(G(z)): 0.22
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.7248, g_loss: 2.0957, D(x): 0.75, D(G(z)): 0.25
# Epoch [110/300], Step [400/600], d_loss: 0.7708, g_loss: 1.4941, D(x): 0.69, D(G(z)): 0.20
# Epoch [110/300], Step [600/600], d_loss: 0.8307, g_loss: 2.4059, D(x): 0.71, D(G(z)): 0.23
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.7719, g_loss: 1.6605, D(x): 0.77, D(G(z)): 0.29
# Epoch [111/300], Step [400/600], d_loss: 0.7990, g_loss: 1.4754, D(x): 0.69, D(G(z)): 0.23
# Epoch [111/300], Step [600/600], d_loss: 0.8091, g_loss: 1.3359, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.8995, g_loss: 1.6948, D(x): 0.77, D(G(z)): 0.34
# Epoch [112/300], Step [400/600], d_loss: 0.9040, g_loss: 1.9756, D(x): 0.68, D(G(z)): 0.19
# Epoch [112/300], Step [600/600], d_loss: 0.9492, g_loss: 1.2624, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.9853, g_loss: 1.9070, D(x): 0.73, D(G(z)): 0.33
# Epoch [113/300], Step [400/600], d_loss: 0.8179, g_loss: 2.3841, D(x): 0.69, D(G(z)): 0.23
# Epoch [113/300], Step [600/600], d_loss: 0.8027, g_loss: 1.9578, D(x): 0.70, D(G(z)): 0.22
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.9777, g_loss: 1.6527, D(x): 0.78, D(G(z)): 0.37
# Epoch [114/300], Step [400/600], d_loss: 0.7178, g_loss: 1.5108, D(x): 0.83, D(G(z)): 0.30
# Epoch [114/300], Step [600/600], d_loss: 0.7419, g_loss: 1.5141, D(x): 0.79, D(G(z)): 0.28
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.9145, g_loss: 1.7370, D(x): 0.73, D(G(z)): 0.31
# Epoch [115/300], Step [400/600], d_loss: 1.0973, g_loss: 1.7177, D(x): 0.66, D(G(z)): 0.30
# Epoch [115/300], Step [600/600], d_loss: 0.8297, g_loss: 1.6678, D(x): 0.67, D(G(z)): 0.22
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.6819, g_loss: 2.3624, D(x): 0.77, D(G(z)): 0.23
# Epoch [116/300], Step [400/600], d_loss: 0.8224, g_loss: 1.4633, D(x): 0.74, D(G(z)): 0.27
# Epoch [116/300], Step [600/600], d_loss: 0.7777, g_loss: 1.7151, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.7137, g_loss: 1.7942, D(x): 0.72, D(G(z)): 0.24
# Epoch [117/300], Step [400/600], d_loss: 0.6561, g_loss: 2.4016, D(x): 0.78, D(G(z)): 0.25
# Epoch [117/300], Step [600/600], d_loss: 1.0174, g_loss: 1.3386, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.8632, g_loss: 1.5768, D(x): 0.77, D(G(z)): 0.35
# Epoch [118/300], Step [400/600], d_loss: 0.8957, g_loss: 1.3139, D(x): 0.74, D(G(z)): 0.34
# Epoch [118/300], Step [600/600], d_loss: 0.6739, g_loss: 1.9877, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.9275, g_loss: 2.0788, D(x): 0.72, D(G(z)): 0.31
# Epoch [119/300], Step [400/600], d_loss: 0.7348, g_loss: 2.0278, D(x): 0.80, D(G(z)): 0.30
# Epoch [119/300], Step [600/600], d_loss: 0.7145, g_loss: 1.8473, D(x): 0.81, D(G(z)): 0.31
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.7627, g_loss: 1.5928, D(x): 0.76, D(G(z)): 0.29
# Epoch [120/300], Step [400/600], d_loss: 0.7765, g_loss: 2.0870, D(x): 0.73, D(G(z)): 0.27
# Epoch [120/300], Step [600/600], d_loss: 0.7999, g_loss: 1.3366, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.8774, g_loss: 1.8649, D(x): 0.70, D(G(z)): 0.27
# Epoch [121/300], Step [400/600], d_loss: 0.8781, g_loss: 1.8457, D(x): 0.65, D(G(z)): 0.20
# Epoch [121/300], Step [600/600], d_loss: 0.7994, g_loss: 1.7356, D(x): 0.75, D(G(z)): 0.28
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.7776, g_loss: 1.7699, D(x): 0.72, D(G(z)): 0.24
# Epoch [122/300], Step [400/600], d_loss: 0.7969, g_loss: 1.8308, D(x): 0.70, D(G(z)): 0.25
# Epoch [122/300], Step [600/600], d_loss: 0.7790, g_loss: 1.9450, D(x): 0.72, D(G(z)): 0.23
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.7823, g_loss: 1.7937, D(x): 0.75, D(G(z)): 0.30
# Epoch [123/300], Step [400/600], d_loss: 0.7912, g_loss: 1.6233, D(x): 0.77, D(G(z)): 0.33
# Epoch [123/300], Step [600/600], d_loss: 0.7246, g_loss: 1.6754, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 1.0278, g_loss: 1.4574, D(x): 0.60, D(G(z)): 0.24
# Epoch [124/300], Step [400/600], d_loss: 0.9707, g_loss: 1.7516, D(x): 0.73, D(G(z)): 0.32
# Epoch [124/300], Step [600/600], d_loss: 0.7996, g_loss: 1.8583, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.8759, g_loss: 1.6543, D(x): 0.74, D(G(z)): 0.33
# Epoch [125/300], Step [400/600], d_loss: 1.0721, g_loss: 1.7502, D(x): 0.69, D(G(z)): 0.37
# Epoch [125/300], Step [600/600], d_loss: 0.7613, g_loss: 1.8325, D(x): 0.73, D(G(z)): 0.24
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 1.1072, g_loss: 1.6363, D(x): 0.65, D(G(z)): 0.32
# Epoch [126/300], Step [400/600], d_loss: 0.9317, g_loss: 1.1950, D(x): 0.73, D(G(z)): 0.32
# Epoch [126/300], Step [600/600], d_loss: 0.9480, g_loss: 1.9253, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.9449, g_loss: 1.6937, D(x): 0.71, D(G(z)): 0.32
# Epoch [127/300], Step [400/600], d_loss: 0.9440, g_loss: 1.5887, D(x): 0.69, D(G(z)): 0.31
# Epoch [127/300], Step [600/600], d_loss: 0.8894, g_loss: 1.8467, D(x): 0.64, D(G(z)): 0.22
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.8694, g_loss: 1.8143, D(x): 0.74, D(G(z)): 0.27
# Epoch [128/300], Step [400/600], d_loss: 1.0170, g_loss: 1.5503, D(x): 0.69, D(G(z)): 0.33
# Epoch [128/300], Step [600/600], d_loss: 1.1602, g_loss: 1.4902, D(x): 0.76, D(G(z)): 0.47
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.8198, g_loss: 1.7289, D(x): 0.76, D(G(z)): 0.32
# Epoch [129/300], Step [400/600], d_loss: 0.8259, g_loss: 1.7050, D(x): 0.67, D(G(z)): 0.22
# Epoch [129/300], Step [600/600], d_loss: 0.8603, g_loss: 1.7225, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.7559, g_loss: 1.6243, D(x): 0.73, D(G(z)): 0.23
# Epoch [130/300], Step [400/600], d_loss: 1.0966, g_loss: 1.7413, D(x): 0.73, D(G(z)): 0.40
# Epoch [130/300], Step [600/600], d_loss: 0.7724, g_loss: 2.3475, D(x): 0.73, D(G(z)): 0.24
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 1.0120, g_loss: 1.8720, D(x): 0.66, D(G(z)): 0.28
# Epoch [131/300], Step [400/600], d_loss: 0.6851, g_loss: 2.0587, D(x): 0.72, D(G(z)): 0.18
# Epoch [131/300], Step [600/600], d_loss: 0.9296, g_loss: 1.9917, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.7924, g_loss: 1.4468, D(x): 0.72, D(G(z)): 0.24
# Epoch [132/300], Step [400/600], d_loss: 0.8817, g_loss: 2.0074, D(x): 0.70, D(G(z)): 0.26
# Epoch [132/300], Step [600/600], d_loss: 1.0524, g_loss: 1.3274, D(x): 0.66, D(G(z)): 0.33
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.9559, g_loss: 1.7211, D(x): 0.67, D(G(z)): 0.29
# Epoch [133/300], Step [400/600], d_loss: 0.9835, g_loss: 1.4812, D(x): 0.72, D(G(z)): 0.33
# Epoch [133/300], Step [600/600], d_loss: 0.8615, g_loss: 1.7105, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.9639, g_loss: 1.4826, D(x): 0.77, D(G(z)): 0.39
# Epoch [134/300], Step [400/600], d_loss: 0.9820, g_loss: 1.4022, D(x): 0.70, D(G(z)): 0.32
# Epoch [134/300], Step [600/600], d_loss: 0.8046, g_loss: 1.6934, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.9708, g_loss: 1.3329, D(x): 0.77, D(G(z)): 0.37
# Epoch [135/300], Step [400/600], d_loss: 0.9058, g_loss: 1.3505, D(x): 0.77, D(G(z)): 0.39
# Epoch [135/300], Step [600/600], d_loss: 0.8822, g_loss: 1.4747, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.9637, g_loss: 1.5561, D(x): 0.64, D(G(z)): 0.26
# Epoch [136/300], Step [400/600], d_loss: 0.7358, g_loss: 1.8892, D(x): 0.69, D(G(z)): 0.19
# Epoch [136/300], Step [600/600], d_loss: 0.7578, g_loss: 1.7238, D(x): 0.69, D(G(z)): 0.19
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.8570, g_loss: 1.9817, D(x): 0.63, D(G(z)): 0.17
# Epoch [137/300], Step [400/600], d_loss: 0.8672, g_loss: 1.8549, D(x): 0.66, D(G(z)): 0.23
# Epoch [137/300], Step [600/600], d_loss: 0.9888, g_loss: 1.4082, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.8875, g_loss: 1.9310, D(x): 0.71, D(G(z)): 0.31
# Epoch [138/300], Step [400/600], d_loss: 1.0742, g_loss: 1.5035, D(x): 0.69, D(G(z)): 0.37
# Epoch [138/300], Step [600/600], d_loss: 0.6938, g_loss: 1.7778, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 1.0318, g_loss: 1.6539, D(x): 0.71, D(G(z)): 0.37
# Epoch [139/300], Step [400/600], d_loss: 0.7413, g_loss: 1.5300, D(x): 0.75, D(G(z)): 0.28
# Epoch [139/300], Step [600/600], d_loss: 0.8379, g_loss: 1.4232, D(x): 0.70, D(G(z)): 0.25
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.8271, g_loss: 1.7457, D(x): 0.75, D(G(z)): 0.30
# Epoch [140/300], Step [400/600], d_loss: 0.8098, g_loss: 1.6388, D(x): 0.73, D(G(z)): 0.28
# Epoch [140/300], Step [600/600], d_loss: 0.9946, g_loss: 1.6534, D(x): 0.66, D(G(z)): 0.29
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.9552, g_loss: 1.5557, D(x): 0.72, D(G(z)): 0.34
# Epoch [141/300], Step [400/600], d_loss: 0.8570, g_loss: 1.6244, D(x): 0.73, D(G(z)): 0.32
# Epoch [141/300], Step [600/600], d_loss: 0.7988, g_loss: 1.5617, D(x): 0.71, D(G(z)): 0.21
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.8040, g_loss: 1.3181, D(x): 0.78, D(G(z)): 0.33
# Epoch [142/300], Step [400/600], d_loss: 0.8467, g_loss: 1.7292, D(x): 0.73, D(G(z)): 0.31
# Epoch [142/300], Step [600/600], d_loss: 0.8619, g_loss: 1.6065, D(x): 0.67, D(G(z)): 0.24
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.8700, g_loss: 1.7834, D(x): 0.68, D(G(z)): 0.26
# Epoch [143/300], Step [400/600], d_loss: 0.9911, g_loss: 1.4686, D(x): 0.73, D(G(z)): 0.38
# Epoch [143/300], Step [600/600], d_loss: 0.8960, g_loss: 1.4653, D(x): 0.64, D(G(z)): 0.22
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.9006, g_loss: 1.5609, D(x): 0.69, D(G(z)): 0.29
# Epoch [144/300], Step [400/600], d_loss: 0.9146, g_loss: 1.7413, D(x): 0.74, D(G(z)): 0.35
# Epoch [144/300], Step [600/600], d_loss: 0.7974, g_loss: 1.6373, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.7570, g_loss: 1.7993, D(x): 0.70, D(G(z)): 0.24
# Epoch [145/300], Step [400/600], d_loss: 0.9133, g_loss: 1.4361, D(x): 0.69, D(G(z)): 0.30
# Epoch [145/300], Step [600/600], d_loss: 0.8381, g_loss: 1.5988, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.9951, g_loss: 1.9743, D(x): 0.68, D(G(z)): 0.33
# Epoch [146/300], Step [400/600], d_loss: 0.8597, g_loss: 1.5892, D(x): 0.70, D(G(z)): 0.26
# Epoch [146/300], Step [600/600], d_loss: 0.9995, g_loss: 1.3142, D(x): 0.75, D(G(z)): 0.40
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 0.9764, g_loss: 1.3431, D(x): 0.64, D(G(z)): 0.28
# Epoch [147/300], Step [400/600], d_loss: 0.9354, g_loss: 2.1021, D(x): 0.66, D(G(z)): 0.25
# Epoch [147/300], Step [600/600], d_loss: 0.8620, g_loss: 1.4825, D(x): 0.75, D(G(z)): 0.33
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.7627, g_loss: 1.6799, D(x): 0.75, D(G(z)): 0.29
# Epoch [148/300], Step [400/600], d_loss: 0.7520, g_loss: 1.8292, D(x): 0.71, D(G(z)): 0.22
# Epoch [148/300], Step [600/600], d_loss: 0.8741, g_loss: 1.7266, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.8570, g_loss: 1.5754, D(x): 0.78, D(G(z)): 0.35
# Epoch [149/300], Step [400/600], d_loss: 1.0771, g_loss: 1.6002, D(x): 0.67, D(G(z)): 0.33
# Epoch [149/300], Step [600/600], d_loss: 0.7746, g_loss: 1.3474, D(x): 0.68, D(G(z)): 0.21
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 1.0088, g_loss: 1.5258, D(x): 0.70, D(G(z)): 0.37
# Epoch [150/300], Step [400/600], d_loss: 1.0840, g_loss: 1.2042, D(x): 0.74, D(G(z)): 0.39
# Epoch [150/300], Step [600/600], d_loss: 0.9364, g_loss: 1.4375, D(x): 0.73, D(G(z)): 0.35
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.9510, g_loss: 1.2952, D(x): 0.77, D(G(z)): 0.39
# Epoch [151/300], Step [400/600], d_loss: 0.8815, g_loss: 1.6167, D(x): 0.72, D(G(z)): 0.31
# Epoch [151/300], Step [600/600], d_loss: 0.8808, g_loss: 1.5719, D(x): 0.67, D(G(z)): 0.24
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.8127, g_loss: 1.6546, D(x): 0.74, D(G(z)): 0.29
# Epoch [152/300], Step [400/600], d_loss: 0.8877, g_loss: 1.6625, D(x): 0.71, D(G(z)): 0.31
# Epoch [152/300], Step [600/600], d_loss: 1.0520, g_loss: 1.4850, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.7380, g_loss: 1.7346, D(x): 0.82, D(G(z)): 0.34
# Epoch [153/300], Step [400/600], d_loss: 0.7478, g_loss: 1.6742, D(x): 0.67, D(G(z)): 0.18
# Epoch [153/300], Step [600/600], d_loss: 0.9285, g_loss: 1.9123, D(x): 0.67, D(G(z)): 0.25
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 1.0733, g_loss: 1.6085, D(x): 0.64, D(G(z)): 0.33
# Epoch [154/300], Step [400/600], d_loss: 0.8585, g_loss: 1.5418, D(x): 0.67, D(G(z)): 0.26
# Epoch [154/300], Step [600/600], d_loss: 0.7780, g_loss: 1.3453, D(x): 0.75, D(G(z)): 0.29
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.9860, g_loss: 1.1171, D(x): 0.71, D(G(z)): 0.34
# Epoch [155/300], Step [400/600], d_loss: 0.7644, g_loss: 1.4708, D(x): 0.77, D(G(z)): 0.29
# Epoch [155/300], Step [600/600], d_loss: 0.9451, g_loss: 1.1628, D(x): 0.73, D(G(z)): 0.32
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.8774, g_loss: 1.6805, D(x): 0.65, D(G(z)): 0.24
# Epoch [156/300], Step [400/600], d_loss: 0.9195, g_loss: 1.1435, D(x): 0.78, D(G(z)): 0.38
# Epoch [156/300], Step [600/600], d_loss: 1.0168, g_loss: 1.4680, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.9052, g_loss: 1.4725, D(x): 0.78, D(G(z)): 0.38
# Epoch [157/300], Step [400/600], d_loss: 0.8605, g_loss: 2.0735, D(x): 0.71, D(G(z)): 0.29
# Epoch [157/300], Step [600/600], d_loss: 0.9844, g_loss: 1.3458, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 1.0791, g_loss: 1.4395, D(x): 0.64, D(G(z)): 0.31
# Epoch [158/300], Step [400/600], d_loss: 0.8554, g_loss: 1.4850, D(x): 0.73, D(G(z)): 0.31
# Epoch [158/300], Step [600/600], d_loss: 0.9410, g_loss: 1.3904, D(x): 0.69, D(G(z)): 0.29
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.8941, g_loss: 1.8369, D(x): 0.74, D(G(z)): 0.33
# Epoch [159/300], Step [400/600], d_loss: 0.9972, g_loss: 1.3672, D(x): 0.66, D(G(z)): 0.33
# Epoch [159/300], Step [600/600], d_loss: 1.0621, g_loss: 1.3588, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.9059, g_loss: 1.2036, D(x): 0.72, D(G(z)): 0.33
# ...
# Epoch [247/300], Step [400/600], d_loss: 0.9475, g_loss: 1.4161, D(x): 0.66, D(G(z)): 0.29
# Epoch [247/300], Step [600/600], d_loss: 0.8277, g_loss: 1.7262, D(x): 0.68, D(G(z)): 0.25
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.9478, g_loss: 1.7253, D(x): 0.72, D(G(z)): 0.36
# Epoch [248/300], Step [400/600], d_loss: 0.7873, g_loss: 1.7490, D(x): 0.76, D(G(z)): 0.31
# Epoch [248/300], Step [600/600], d_loss: 0.8888, g_loss: 1.4176, D(x): 0.76, D(G(z)): 0.35
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 1.0498, g_loss: 1.2298, D(x): 0.63, D(G(z)): 0.30
# Epoch [249/300], Step [400/600], d_loss: 0.7079, g_loss: 1.4583, D(x): 0.75, D(G(z)): 0.28
# Epoch [249/300], Step [600/600], d_loss: 1.1882, g_loss: 1.8976, D(x): 0.64, D(G(z)): 0.34
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 1.0897, g_loss: 1.4501, D(x): 0.62, D(G(z)): 0.27
# Epoch [250/300], Step [400/600], d_loss: 1.0088, g_loss: 1.2669, D(x): 0.65, D(G(z)): 0.30
# Epoch [250/300], Step [600/600], d_loss: 0.9676, g_loss: 1.5374, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.9780, g_loss: 1.4878, D(x): 0.76, D(G(z)): 0.41
# Epoch [251/300], Step [400/600], d_loss: 1.0586, g_loss: 1.6439, D(x): 0.67, D(G(z)): 0.32
# Epoch [251/300], Step [600/600], d_loss: 0.8048, g_loss: 1.5266, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.9333, g_loss: 1.7014, D(x): 0.69, D(G(z)): 0.30
# Epoch [252/300], Step [400/600], d_loss: 0.8840, g_loss: 1.5726, D(x): 0.74, D(G(z)): 0.30
# Epoch [252/300], Step [600/600], d_loss: 1.1421, g_loss: 1.2520, D(x): 0.60, D(G(z)): 0.33
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 1.0161, g_loss: 1.2630, D(x): 0.68, D(G(z)): 0.34
# Epoch [253/300], Step [400/600], d_loss: 0.8600, g_loss: 1.6200, D(x): 0.69, D(G(z)): 0.28
# Epoch [253/300], Step [600/600], d_loss: 0.9477, g_loss: 1.3638, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.9785, g_loss: 1.8889, D(x): 0.67, D(G(z)): 0.31
# Epoch [254/300], Step [400/600], d_loss: 0.9510, g_loss: 1.4669, D(x): 0.66, D(G(z)): 0.29
# Epoch [254/300], Step [600/600], d_loss: 1.0330, g_loss: 1.5954, D(x): 0.62, D(G(z)): 0.25
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.9621, g_loss: 1.3888, D(x): 0.63, D(G(z)): 0.25
# Epoch [255/300], Step [400/600], d_loss: 0.8136, g_loss: 1.4756, D(x): 0.72, D(G(z)): 0.28
# Epoch [255/300], Step [600/600], d_loss: 1.0545, g_loss: 1.4980, D(x): 0.67, D(G(z)): 0.36
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.8557, g_loss: 1.4778, D(x): 0.73, D(G(z)): 0.32
# Epoch [256/300], Step [400/600], d_loss: 1.1493, g_loss: 1.6038, D(x): 0.76, D(G(z)): 0.44
# Epoch [256/300], Step [600/600], d_loss: 0.9524, g_loss: 1.5629, D(x): 0.74, D(G(z)): 0.35
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 1.0196, g_loss: 1.4969, D(x): 0.77, D(G(z)): 0.42
# Epoch [257/300], Step [400/600], d_loss: 0.8939, g_loss: 1.6984, D(x): 0.67, D(G(z)): 0.27
# Epoch [257/300], Step [600/600], d_loss: 0.8222, g_loss: 1.8815, D(x): 0.73, D(G(z)): 0.29
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.9200, g_loss: 1.7681, D(x): 0.61, D(G(z)): 0.19
# Epoch [258/300], Step [400/600], d_loss: 0.8441, g_loss: 1.5672, D(x): 0.69, D(G(z)): 0.27
# Epoch [258/300], Step [600/600], d_loss: 0.8748, g_loss: 1.6385, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.9343, g_loss: 1.7330, D(x): 0.72, D(G(z)): 0.35
# Epoch [259/300], Step [400/600], d_loss: 1.0819, g_loss: 1.9083, D(x): 0.62, D(G(z)): 0.29
# Epoch [259/300], Step [600/600], d_loss: 0.9839, g_loss: 1.3230, D(x): 0.73, D(G(z)): 0.37
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 1.0833, g_loss: 1.6368, D(x): 0.59, D(G(z)): 0.22
# Epoch [260/300], Step [400/600], d_loss: 0.9559, g_loss: 1.6125, D(x): 0.71, D(G(z)): 0.32
# Epoch [260/300], Step [600/600], d_loss: 1.0153, g_loss: 1.2335, D(x): 0.74, D(G(z)): 0.36
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 1.0699, g_loss: 1.6094, D(x): 0.64, D(G(z)): 0.30
# Epoch [261/300], Step [400/600], d_loss: 0.7123, g_loss: 1.5455, D(x): 0.72, D(G(z)): 0.24
# Epoch [261/300], Step [600/600], d_loss: 1.0645, g_loss: 1.1349, D(x): 0.67, D(G(z)): 0.36
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.8149, g_loss: 1.2879, D(x): 0.76, D(G(z)): 0.31
# Epoch [262/300], Step [400/600], d_loss: 0.8727, g_loss: 1.6314, D(x): 0.71, D(G(z)): 0.30
# Epoch [262/300], Step [600/600], d_loss: 1.0022, g_loss: 1.9245, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.9368, g_loss: 1.7387, D(x): 0.70, D(G(z)): 0.32
# Epoch [263/300], Step [400/600], d_loss: 0.7941, g_loss: 1.6554, D(x): 0.69, D(G(z)): 0.25
# Epoch [263/300], Step [600/600], d_loss: 0.9367, g_loss: 1.4500, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.9641, g_loss: 1.4204, D(x): 0.68, D(G(z)): 0.33
# Epoch [264/300], Step [400/600], d_loss: 0.9035, g_loss: 1.3684, D(x): 0.72, D(G(z)): 0.30
# Epoch [264/300], Step [600/600], d_loss: 1.0566, g_loss: 1.7326, D(x): 0.64, D(G(z)): 0.32
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 1.0907, g_loss: 1.4558, D(x): 0.71, D(G(z)): 0.41
# Epoch [265/300], Step [400/600], d_loss: 0.9071, g_loss: 1.2541, D(x): 0.66, D(G(z)): 0.29
# Epoch [265/300], Step [600/600], d_loss: 0.9156, g_loss: 1.7186, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.9400, g_loss: 1.3917, D(x): 0.68, D(G(z)): 0.32
# Epoch [266/300], Step [400/600], d_loss: 1.0142, g_loss: 1.3501, D(x): 0.62, D(G(z)): 0.28
# Epoch [266/300], Step [600/600], d_loss: 0.9872, g_loss: 1.6566, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.8389, g_loss: 1.6122, D(x): 0.71, D(G(z)): 0.27
# Epoch [267/300], Step [400/600], d_loss: 1.0743, g_loss: 1.3890, D(x): 0.76, D(G(z)): 0.42
# Epoch [267/300], Step [600/600], d_loss: 0.8908, g_loss: 1.6076, D(x): 0.69, D(G(z)): 0.31
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.8713, g_loss: 1.4455, D(x): 0.68, D(G(z)): 0.26
# Epoch [268/300], Step [400/600], d_loss: 0.9575, g_loss: 1.5242, D(x): 0.65, D(G(z)): 0.27
# Epoch [268/300], Step [600/600], d_loss: 1.0105, g_loss: 1.7572, D(x): 0.65, D(G(z)): 0.30
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.9203, g_loss: 1.4098, D(x): 0.68, D(G(z)): 0.29
# Epoch [269/300], Step [400/600], d_loss: 0.9675, g_loss: 1.6468, D(x): 0.61, D(G(z)): 0.22
# Epoch [269/300], Step [600/600], d_loss: 0.8207, g_loss: 1.6888, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.9376, g_loss: 1.3675, D(x): 0.71, D(G(z)): 0.33
# Epoch [270/300], Step [400/600], d_loss: 0.9496, g_loss: 1.2395, D(x): 0.68, D(G(z)): 0.32
# Epoch [270/300], Step [600/600], d_loss: 1.0400, g_loss: 1.4856, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.9576, g_loss: 1.5258, D(x): 0.67, D(G(z)): 0.27
# Epoch [271/300], Step [400/600], d_loss: 0.9699, g_loss: 1.6971, D(x): 0.68, D(G(z)): 0.31
# Epoch [271/300], Step [600/600], d_loss: 0.8930, g_loss: 1.2267, D(x): 0.75, D(G(z)): 0.36
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.9011, g_loss: 1.7630, D(x): 0.69, D(G(z)): 0.27
# Epoch [272/300], Step [400/600], d_loss: 0.9570, g_loss: 1.2225, D(x): 0.72, D(G(z)): 0.34
# Epoch [272/300], Step [600/600], d_loss: 0.8476, g_loss: 1.8464, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 1.0737, g_loss: 1.4615, D(x): 0.62, D(G(z)): 0.30
# Epoch [273/300], Step [400/600], d_loss: 0.8893, g_loss: 1.8121, D(x): 0.69, D(G(z)): 0.31
# Epoch [273/300], Step [600/600], d_loss: 1.0258, g_loss: 1.4650, D(x): 0.62, D(G(z)): 0.29
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.9522, g_loss: 1.8001, D(x): 0.66, D(G(z)): 0.26
# Epoch [274/300], Step [400/600], d_loss: 0.9767, g_loss: 1.7813, D(x): 0.64, D(G(z)): 0.28
# Epoch [274/300], Step [600/600], d_loss: 0.8139, g_loss: 1.5588, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.9508, g_loss: 1.7547, D(x): 0.67, D(G(z)): 0.28
# Epoch [275/300], Step [400/600], d_loss: 1.0983, g_loss: 1.4740, D(x): 0.63, D(G(z)): 0.31
# Epoch [275/300], Step [600/600], d_loss: 1.0116, g_loss: 1.5163, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.8565, g_loss: 1.3783, D(x): 0.73, D(G(z)): 0.33
# Epoch [276/300], Step [400/600], d_loss: 1.0730, g_loss: 1.8978, D(x): 0.69, D(G(z)): 0.37
# Epoch [276/300], Step [600/600], d_loss: 0.9494, g_loss: 1.3931, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 1.1870, g_loss: 1.4732, D(x): 0.63, D(G(z)): 0.33
# Epoch [277/300], Step [400/600], d_loss: 0.9938, g_loss: 1.5626, D(x): 0.65, D(G(z)): 0.31
# Epoch [277/300], Step [600/600], d_loss: 1.0028, g_loss: 1.5284, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.7654, g_loss: 1.4624, D(x): 0.73, D(G(z)): 0.27
# Epoch [278/300], Step [400/600], d_loss: 0.8847, g_loss: 1.6209, D(x): 0.76, D(G(z)): 0.37
# Epoch [278/300], Step [600/600], d_loss: 0.9562, g_loss: 1.6958, D(x): 0.60, D(G(z)): 0.23
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 1.0195, g_loss: 1.6683, D(x): 0.65, D(G(z)): 0.32
# Epoch [279/300], Step [400/600], d_loss: 0.8738, g_loss: 1.2572, D(x): 0.71, D(G(z)): 0.31
# Epoch [279/300], Step [600/600], d_loss: 1.0036, g_loss: 1.4898, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.9342, g_loss: 1.9464, D(x): 0.73, D(G(z)): 0.33
# Epoch [280/300], Step [400/600], d_loss: 0.8970, g_loss: 1.2549, D(x): 0.76, D(G(z)): 0.35
# Epoch [280/300], Step [600/600], d_loss: 0.8101, g_loss: 1.6892, D(x): 0.67, D(G(z)): 0.21
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.9930, g_loss: 1.4835, D(x): 0.65, D(G(z)): 0.29
# Epoch [281/300], Step [400/600], d_loss: 0.7772, g_loss: 1.6195, D(x): 0.69, D(G(z)): 0.19
# Epoch [281/300], Step [600/600], d_loss: 1.0234, g_loss: 1.7988, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.9597, g_loss: 1.4033, D(x): 0.68, D(G(z)): 0.32
# Epoch [282/300], Step [400/600], d_loss: 0.9139, g_loss: 1.3196, D(x): 0.71, D(G(z)): 0.32
# Epoch [282/300], Step [600/600], d_loss: 0.9678, g_loss: 1.3675, D(x): 0.66, D(G(z)): 0.29
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.8578, g_loss: 1.5744, D(x): 0.72, D(G(z)): 0.30
# Epoch [283/300], Step [400/600], d_loss: 0.8683, g_loss: 1.4042, D(x): 0.73, D(G(z)): 0.32
# Epoch [283/300], Step [600/600], d_loss: 1.0892, g_loss: 1.5073, D(x): 0.68, D(G(z)): 0.37
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.9762, g_loss: 1.5073, D(x): 0.68, D(G(z)): 0.33
# Epoch [284/300], Step [400/600], d_loss: 1.0086, g_loss: 1.3972, D(x): 0.71, D(G(z)): 0.31
# Epoch [284/300], Step [600/600], d_loss: 0.9791, g_loss: 1.5901, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.9517, g_loss: 1.9962, D(x): 0.64, D(G(z)): 0.26
# Epoch [285/300], Step [400/600], d_loss: 0.8551, g_loss: 1.2386, D(x): 0.73, D(G(z)): 0.32
# Epoch [285/300], Step [600/600], d_loss: 0.8085, g_loss: 1.4005, D(x): 0.79, D(G(z)): 0.33
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.8582, g_loss: 1.6057, D(x): 0.67, D(G(z)): 0.27
# Epoch [286/300], Step [400/600], d_loss: 0.7720, g_loss: 1.3237, D(x): 0.71, D(G(z)): 0.26
# Epoch [286/300], Step [600/600], d_loss: 0.9064, g_loss: 1.4291, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.9631, g_loss: 1.2623, D(x): 0.73, D(G(z)): 0.37
# Epoch [287/300], Step [400/600], d_loss: 0.8599, g_loss: 1.5445, D(x): 0.83, D(G(z)): 0.38
# Epoch [287/300], Step [600/600], d_loss: 1.1007, g_loss: 1.5575, D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.9251, g_loss: 1.7022, D(x): 0.65, D(G(z)): 0.25
# Epoch [288/300], Step [400/600], d_loss: 0.9599, g_loss: 1.6131, D(x): 0.77, D(G(z)): 0.37
# Epoch [288/300], Step [600/600], d_loss: 0.8646, g_loss: 1.4292, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.9590, g_loss: 1.4958, D(x): 0.72, D(G(z)): 0.35
# Epoch [289/300], Step [400/600], d_loss: 0.8509, g_loss: 1.5162, D(x): 0.72, D(G(z)): 0.29
# Epoch [289/300], Step [600/600], d_loss: 0.8367, g_loss: 1.4023, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.9194, g_loss: 1.5664, D(x): 0.70, D(G(z)): 0.31
# Epoch [290/300], Step [400/600], d_loss: 0.8905, g_loss: 1.4499, D(x): 0.70, D(G(z)): 0.28
# Epoch [290/300], Step [600/600], d_loss: 0.8476, g_loss: 1.5703, D(x): 0.72, D(G(z)): 0.28
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.8528, g_loss: 1.4491, D(x): 0.68, D(G(z)): 0.25
# Epoch [291/300], Step [400/600], d_loss: 0.9808, g_loss: 2.2400, D(x): 0.61, D(G(z)): 0.20
# Epoch [291/300], Step [600/600], d_loss: 1.0147, g_loss: 1.5477, D(x): 0.71, D(G(z)): 0.37
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.8478, g_loss: 1.8237, D(x): 0.66, D(G(z)): 0.24
# Epoch [292/300], Step [400/600], d_loss: 0.8691, g_loss: 1.4689, D(x): 0.66, D(G(z)): 0.24
# Epoch [292/300], Step [600/600], d_loss: 0.8696, g_loss: 1.8248, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.9088, g_loss: 1.5889, D(x): 0.76, D(G(z)): 0.36
# Epoch [293/300], Step [400/600], d_loss: 0.8441, g_loss: 1.2124, D(x): 0.81, D(G(z)): 0.36
# Epoch [293/300], Step [600/600], d_loss: 0.8668, g_loss: 1.4882, D(x): 0.76, D(G(z)): 0.36
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.8634, g_loss: 1.7242, D(x): 0.66, D(G(z)): 0.26
# Epoch [294/300], Step [400/600], d_loss: 0.8552, g_loss: 1.4499, D(x): 0.72, D(G(z)): 0.30
# Epoch [294/300], Step [600/600], d_loss: 0.9676, g_loss: 1.3785, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.9832, g_loss: 1.6296, D(x): 0.69, D(G(z)): 0.33
# Epoch [295/300], Step [400/600], d_loss: 1.1429, g_loss: 1.8595, D(x): 0.55, D(G(z)): 0.21
# Epoch [295/300], Step [600/600], d_loss: 0.8580, g_loss: 1.6966, D(x): 0.75, D(G(z)): 0.31
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.9962, g_loss: 1.7880, D(x): 0.62, D(G(z)): 0.23
# Epoch [296/300], Step [400/600], d_loss: 0.9960, g_loss: 1.9263, D(x): 0.69, D(G(z)): 0.32
# Epoch [296/300], Step [600/600], d_loss: 0.7245, g_loss: 1.7631, D(x): 0.77, D(G(z)): 0.28
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.8606, g_loss: 1.6328, D(x): 0.73, D(G(z)): 0.32
# Epoch [297/300], Step [400/600], d_loss: 0.9989, g_loss: 1.5357, D(x): 0.68, D(G(z)): 0.35
# Epoch [297/300], Step [600/600], d_loss: 0.9410, g_loss: 1.3589, D(x): 0.62, D(G(z)): 0.21
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.8247, g_loss: 1.8222, D(x): 0.72, D(G(z)): 0.24
# Epoch [298/300], Step [400/600], d_loss: 0.9557, g_loss: 1.5565, D(x): 0.65, D(G(z)): 0.29
# Epoch [298/300], Step [600/600], d_loss: 0.9353, g_loss: 1.4401, D(x): 0.66, D(G(z)): 0.26
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.9566, g_loss: 1.6777, D(x): 0.68, D(G(z)): 0.29
# Epoch [299/300], Step [400/600], d_loss: 0.9208, g_loss: 1.5794, D(x): 0.67, D(G(z)): 0.26
# Epoch [299/300], Step [600/600], d_loss: 0.8492, g_loss: 1.7124, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0300.png
# CPU times: total: 2h 26min 19s
# Wall time: 2h 3min 17s

# %% [markdown]
# 现在我们已经训练了模型，我们可以保存检查点。

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# 以下是在训练的第10、50、100和300个时期后生成的图像的样子。

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %% [markdown]
# 我们可以使用OpenCV将每个时期后生成的样本图像组合成视频，从而可视化训练过程。

# %% [markdown]
# 我们还可以可视化随时间变化的损失。可视化损失对于调试训练过程非常有用。对于GANs，我们期望生成器的损失随时间降低，而鉴别器的损失不会过高。

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# ## 作业
# 请大家参考上述代码，使用动漫脸数据集，它由超过63,000个裁剪的动漫脸组成。请注意，生成建模是一项无监督学习任务，因此图像没有任何标签。利用生成对抗网络生成新的图像；
#
# ![alt text](https://i.imgur.com/NaKtJs0.png)
#
# 注意：
#
# 1，数据集联系助教【程骏 QQ：7879883】
# 2，大家可以参考[这个项目实现](https://jovian.com/outlink?url=https%3A%2F%2Fwww.kaggle.com%2Fsplcher%2Fstarter-anime-face-dataset)

# %%
# %matplotlib inline
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
from tqdm import tqdm  

# ====================== 核心参数配置 ======================
# 设置随机种子，保证结果可复现
seed = 6969
random.seed(seed)
torch.manual_seed(seed)

# ************************ 重点修改 ************************
# 数据集根目录（本地路径），需按照ImageFolder要求组织：
# 目录结构示例：
# anime_faces/
#   └── faces/          # 分类文件夹（名称任意，因为是无监督）
#       ├── 0001.png
#       ├── 0002.png
#       └── ...
dataroot = "/workspace/img"  # 替换为你的动漫脸数据集根目录

# 训练参数（可根据硬件调整）
workers = 0  # 本地运行建议设为0，避免多线程问题
batch_size = 64  # 显存不足可减小（如32/16）
image_size = 64  # 图像尺寸（固定64x64，匹配网络结构）
nc = 3  # 图像通道数（3=RGB，1=灰度）
nz = 100  # 噪声向量维度
ngf = 64  # 生成器特征图维度
ndf = 64  # 判别器特征图维度
num_epochs = 10  # 新手先跑10轮测试，显存充足可增至50+
lr = 0.0002  # 学习率
beta1 = 0.5  # Adam优化器beta1参数
ngpu = 1  # GPU数量（0=CPU，1=单GPU）

# ====================== 数据加载与预处理 ======================
# 检查数据集路径是否存在
if not os.path.exists(dataroot):
    raise FileNotFoundError(f"数据集路径不存在：{dataroot}\n请确认路径正确，并按ImageFolder结构组织数据集")

# 创建数据集（ImageFolder要求根目录下有子文件夹存放图片）
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),  # 归一化到[-1,1]，匹配Tanh输出
])
dataset = dset.ImageFolder(root=dataroot, transform=transform)

# 创建数据加载器
dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=workers
)

# 选择训练设备（自动检测GPU/CPU）
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
print(f"使用设备：{device}")

# 可视化训练样本（验证数据加载是否正常）
try:
    real_batch = next(iter(dataloader))
    plt.figure(figsize=(8, 8))
    plt.axis("off")
    plt.title("Training Images")
    plt.imshow(np.transpose(vutils.make_grid(
        real_batch[0].to(device)[:64], padding=2, normalize=True
    ).cpu(), (1, 2, 0)))
    plt.show()
except Exception as e:
    print(f"数据加载可视化失败：{e}")

# ====================== 网络权重初始化 ======================
def weights_init(m):
    """初始化网络权重（均值0，标准差0.02）"""
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# ====================== 生成器（Generator） ======================
class Generator(nn.Module):
    def __init__(self, ngpu):
        super(Generator, self).__init__()
        self.ngpu = ngpu
        # 转置卷积：从100维噪声→64x64 RGB图像
        self.main = nn.Sequential(
            nn.ConvTranspose2d(nz, ngf*8, 4, 1, 0, bias=False),  # 1x1 → 4x4
            nn.BatchNorm2d(ngf*8),
            nn.ReLU(True),
            
            nn.ConvTranspose2d(ngf*8, ngf*4, 4, 2, 1, bias=False),  # 4x4 → 8x8
            nn.BatchNorm2d(ngf*4),
            nn.ReLU(True),
            
            nn.ConvTranspose2d(ngf*4, ngf*2, 4, 2, 1, bias=False),  # 8x8 → 16x16
            nn.BatchNorm2d(ngf*2),
            nn.ReLU(True),
            
            nn.ConvTranspose2d(ngf*2, ngf, 4, 2, 1, bias=False),  # 16x16 → 32x32
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            
            nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False),  # 32x32 → 64x64
            nn.Tanh()  # 输出[-1,1]，匹配图像归一化范围
        )

    def forward(self, input):
        return self.main(input)

# 初始化生成器并加载到设备
netG = Generator(ngpu).to(device)
if (device.type == 'cuda') and (ngpu > 1):
    netG = nn.DataParallel(netG, list(range(ngpu)))
netG.apply(weights_init)  # 应用权重初始化
print("生成器网络结构：")
print(netG)

# ====================== 判别器（Discriminator） ======================
class Discriminator(nn.Module):
    def __init__(self, ngpu):
        super(Discriminator, self).__init__()
        self.ngpu = ngpu
        # 卷积：64x64 RGB图像→1维判别结果（真假）
        self.main = nn.Sequential(
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),  # 64x64 → 32x32
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(ndf, ndf*2, 4, 2, 1, bias=False),  # 32x32 → 16x16
            nn.BatchNorm2d(ndf*2),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(ndf*2, ndf*4, 4, 2, 1, bias=False),  # 16x16 → 8x8
            nn.BatchNorm2d(ndf*4),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(ndf*4, ndf*8, 4, 2, 1, bias=False),  # 8x8 → 4x4
            nn.BatchNorm2d(ndf*8),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Conv2d(ndf*8, 1, 4, 1, 0, bias=False),  # 4x4 → 1x1
            nn.Sigmoid()  # 输出[0,1]，表示真假概率
        )

    def forward(self, input):
        return self.main(input)

# 初始化判别器并加载到设备
netD = Discriminator(ngpu).to(device)
if (device.type == 'cuda') and (ngpu > 1):
    netD = nn.DataParallel(netD, list(range(ngpu)))
netD.apply(weights_init)
print("\n判别器网络结构：")
print(netD)

# ====================== 损失函数与优化器 ======================
criterion = nn.BCELoss()  # 二分类交叉熵损失（匹配Sigmoid输出）
fixed_noise = torch.randn(64, nz, 1, 1, device=device)  # 固定噪声，用于可视化生成进度

# 优化器
optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# ====================== 训练循环 ======================
print("\n开始训练...")
img_list = []  # 存储生成的图像
G_losses = []   # 生成器损失
D_losses = []   # 判别器损失
iters = 0

for epoch in range(num_epochs):
    # 添加进度条，方便查看训练进度
    pbar = tqdm(enumerate(dataloader), total=len(dataloader), desc=f"Epoch {epoch+1}/{num_epochs}")
    
    for i, data in pbar:
        ############################
        # 训练判别器：max log(D(x)) + log(1 - D(G(z)))
        ###########################
        # 1. 训练真实图像
        netD.zero_grad()
        real_cpu = data[0].to(device)
        b_size = real_cpu.size(0)
        label = torch.full((b_size,), 1.0, device=device)  # 真实标签=1
        output = netD(real_cpu).view(-1)
        errD_real = criterion(output, label)
        errD_real.backward()
        D_x = output.mean().item()

        # 2. 训练生成的假图像
        noise = torch.randn(b_size, nz, 1, 1, device=device)
        fake = netG(noise)
        label.fill_(0.0)  # 假标签=0
        output = netD(fake.detach()).view(-1)
        errD_fake = criterion(output, label)
        errD_fake.backward()
        D_G_z1 = output.mean().item()

        # 总损失并更新判别器
        errD = errD_real + errD_fake
        optimizerD.step()

        ############################
        # 训练生成器：max log(D(G(z)))
        ###########################
        netG.zero_grad()
        label.fill_(1.0)  # 生成器希望判别器把假图像判为真（标签=1）
        output = netD(fake).view(-1)
        errG = criterion(output, label)
        errG.backward()
        D_G_z2 = output.mean().item()
        optimizerG.step()

        # 更新进度条信息
        pbar.set_postfix({
            'Loss_D': f'{errD.item():.4f}',
            'Loss_G': f'{errG.item():.4f}',
            'D(x)': f'{D_x:.4f}',
            'D(G(z))': f'{D_G_z1:.4f}/{D_G_z2:.4f}'
        })

        # 记录损失
        G_losses.append(errG.item())
        D_losses.append(errD.item())

        # 保存生成的图像（用于后续可视化）
        if (iters % 250 == 0) or ((epoch == num_epochs-1) and (i == len(dataloader)-1)):
            with torch.no_grad():
                fake = netG(fixed_noise).detach().cpu()
            img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

        iters += 1
    pbar.close()

# ====================== 结果可视化 ======================
# 1. 绘制损失曲线
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(G_losses, label="Generator")
plt.plot(D_losses, label="Discriminator")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# 2. 生成动画（展示训练过程中生成图像的变化）
fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i, (1,2,0)), animated=True)] for i in img_list]
ani = animation.ArtistAnimation(fig, ims, interval=1000, repeat_delay=1000, blit=True)
HTML(ani.to_jshtml())

# 3. 对比真实图像和最终生成的假图像
real_batch = next(iter(dataloader))
plt.figure(figsize=(15,15))

# 真实图像
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(vutils.make_grid(
    real_batch[0].to(device)[:64], padding=5, normalize=True
).cpu(), (1,2,0)))

# 生成的假图像
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1], (1,2,0)))
plt.show()
# Out:
# 使用设备：cuda:0
# /root/.pyenv/versions/3.11.1/lib/python3.11/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 生成器网络结构：
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )
#
# 判别器网络结构：
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )
#
# 开始训练...
# Epoch 1/10: 100%|██████████| 89/89 [00:05<00:00, 16.06it/s, Loss_D=0.9974, Loss_G=6.9025, D(x)=0.7378, D(G(z))=0.2425/0.0030]
# Epoch 2/10: 100%|██████████| 89/89 [00:04<00:00, 20.00it/s, Loss_D=0.6438, Loss_G=6.3841, D(x)=0.8317, D(G(z))=0.1935/0.0025]
# Epoch 3/10: 100%|██████████| 89/89 [00:04<00:00, 19.96it/s, Loss_D=0.3863, Loss_G=5.4896, D(x)=0.7607, D(G(z))=0.0161/0.0085]
# Epoch 4/10: 100%|██████████| 89/89 [00:04<00:00, 20.03it/s, Loss_D=0.8596, Loss_G=8.3540, D(x)=0.6561, D(G(z))=0.0023/0.0006]
# Epoch 5/10: 100%|██████████| 89/89 [00:04<00:00, 20.25it/s, Loss_D=1.6054, Loss_G=10.3016, D(x)=0.9509, D(G(z))=0.6461/0.0002]
# Epoch 6/10: 100%|██████████| 89/89 [00:04<00:00, 20.39it/s, Loss_D=0.6068, Loss_G=6.7212, D(x)=0.9539, D(G(z))=0.3769/0.0022]
# Epoch 7/10: 100%|██████████| 89/89 [00:04<00:00, 20.02it/s, Loss_D=0.4465, Loss_G=5.7071, D(x)=0.8954, D(G(z))=0.2323/0.0056]
# Epoch 8/10: 100%|██████████| 89/89 [00:04<00:00, 19.68it/s, Loss_D=0.1981, Loss_G=6.2472, D(x)=0.8661, D(G(z))=0.0117/0.0047]
# Epoch 9/10: 100%|██████████| 89/89 [00:04<00:00, 20.35it/s, Loss_D=0.3574, Loss_G=3.5337, D(x)=0.9016, D(G(z))=0.1754/0.0654]
# Epoch 10/10: 100%|██████████| 89/89 [00:04<00:00, 20.37it/s, Loss_D=0.5470, Loss_G=6.1198, D(x)=0.6441, D(G(z))=0.0056/0.0052]
